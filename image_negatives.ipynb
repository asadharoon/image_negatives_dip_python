# %% [markdown]
# Note: I am Using Scipy v1.1.0. In case of any errors you can install scipy 1.1.0 by the following command:
# pip install scipy==1.1.0

# %%
import scipy
scipy.__version__
# Out:
# '1.1.0'

# %% [markdown]
# To download images Click on this url: https://drive.google.com/drive/folders/1pcaTwofZGfoCxZ3Hv2X6vW6xf_1i88eb?usp=sharing

# %% [markdown]
# # Import Libraries

# %%
from skimage import data
from scipy.misc import imread, imresize
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt

# %% [markdown]
# # Image Negatives Transformation

# %% [markdown]
# Formula of Image Negative Transformation is:
# s =(L-1)-r

# %% [markdown]
# # Original Image

# %%
original_image =imread('sydney.png',True, 'L')    #read image as grey scale image
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Processed Image

# %%
processed_image =original_image.copy()

# %%
greyscale_image =imread('sydney.png',True, 'L')    #read image as grey scale image
greyscale_image =greyscale_image.astype(np.uint8)

print(greyscale_image.dtype)
greyscale_image=(256-1)-greyscale_image
processed_img=greyscale_image.copy()
print(np.amin(processed_img),np.amax(processed_img))
# Out:
# uint8
# 0 255
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
processed_img[processed_img<0]=0
processed_img[processed_img>=255]=255

# %%
fig, axes = plt.subplots(1, 2)
ax = axes.ravel()

ax[0].imshow(original_image,cmap=plt.cm.gray,interpolation='bilinear')
ax[0].set_title("Original")
ax[1].imshow(processed_img, cmap=plt.cm.gray,interpolation='bilinear')
ax[1].set_title("Image Negatives")
plt.imshow(processed_image,cmap=plt.cm.gray)

# %% [markdown]
# # Demo of Array

# %%
print(original_image[1:5,1:5])
print(greyscale_image[1:5,1:5])
# Out:
# [[189. 191. 190. 191.]
#  [189. 190. 191. 192.]
#  [191. 191. 192. 192.]
#  [192. 192. 193. 193.]]
# [[66 64 65 64]
#  [66 65 64 63]
#  [64 64 63 63]
#  [63 63 62 62]]
